# %%
# imports
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# load in google's mobility data
# mobility data source: Google LLC "Google COVID-19 Community Mobility Reports".
# https://www.google.com/covid19/mobility/ Accessed: 6/12/2020.
data = "./Global_Mobility_Report.csv"
mobility_df = pd.read_csv(data, low_memory = False)

# %%
# check out the data
mobility_df.sample(10)
# Out:
#        country_region_code  country_region       sub_region_1  \
# 398803                  US   United States               Ohio
# 65884                   GB  United Kingdom             Orkney
# 469678                  US   United States            Vermont
# 209581                  US   United States            Arizona
# 386675                  US   United States     North Carolina
# 126492                  MX          Mexico            Hidalgo
# 379862                  US   United States           New York
# 17017                   BR          Brazil  State of Rondônia
# 170519                  RO         Romania            Prahova
# 364850                  US   United States           Nebraska
#
#              sub_region_2 iso_3166_2_code  census_fips_code        date  \
# 398803      Fulton County             NaN           39051.0  2020-02-21
# 65884                 NaN          GB-ORK               NaN  2020-04-30
# 469678  Bennington County             NaN           50003.0  2020-03-12
# 209581      La Paz County             NaN            4012.0  2020-06-04
# 386675       Gates County             NaN           37073.0  2020-04-13
# 126492                NaN          MX-HID               NaN  2020-02-15
# 379862      Otsego County             NaN           36077.0  2020-05-17
# 17017                 NaN           BR-RO               NaN  2020-04-29
# 170519                NaN           RO-PH               NaN  2020-06-06
# 364850     Madison County             NaN           31119.0  2020-04-29
#
#         retail_and_recreation_percent_change_from_baseline  \
# 398803                                                3.0
# 65884                                                 NaN
# 469678                                                3.0
# 209581                                              -45.0
# 386675                                                NaN
# 126492                                                5.0
# 379862                                              -17.0
# 17017                                               -34.0
# 170519                                              -23.0
# 364850                                              -24.0
#
#         grocery_and_pharmacy_percent_change_from_baseline  \
# 398803                                               -3.0
# 65884                                                 NaN
# 469678                                               27.0
# 209581                                              -34.0
# 386675                                                NaN
# 126492                                                4.0
# 379862                                                6.0
# 17017                                                -8.0
# 170519                                                3.0
# 364850                                               -8.0
#
#         parks_percent_change_from_baseline  \
# 398803                                 NaN
# 65884                                  NaN
# 469678                                 NaN
# 209581                               -60.0
# 386675                                 NaN
# 126492                                12.0
# 379862                                 NaN
# 17017                                -20.0
# 170519                               -14.0
# 364850                                 NaN
#
#         transit_stations_percent_change_from_baseline  \
# 398803                                            NaN
# 65884                                             NaN
# 469678                                            NaN
# 209581                                          -18.0
# 386675                                            NaN
# 126492                                           -8.0
# 379862                                            NaN
# 17017                                           -56.0
# 170519                                           -4.0
# 364850                                            NaN
#
#         workplaces_percent_change_from_baseline  \
# 398803                                      2.0
# 65884                                     -61.0
# 469678                                     -3.0
# 209581                                    -24.0
# 386675                                    -37.0
# 126492                                      5.0
# 379862                                    -20.0
# 17017                                     -14.0
# 170519                                      8.0
# 364850                                    -30.0
#
#         residential_percent_change_from_baseline
# 398803                                      -1.0
# 65884                                        NaN
# 469678                                       1.0
# 209581                                       NaN
# 386675                                       NaN
# 126492                                      -1.0
# 379862                                       NaN
# 17017                                       11.0
# 170519                                      -2.0
# 364850                                      13.0

# %% [markdown]
# ### Simple EDA

# %%
print("Mobility data dimensions: {}".format(mobility_df.shape))
# Out:
# Mobility data dimensions: (516697, 13)

# %%
mobility_df.dtypes
# Out:
# country_region_code                                    object
# country_region                                         object
# sub_region_1                                           object
# sub_region_2                                           object
# iso_3166_2_code                                        object
# census_fips_code                                      float64
# date                                                   object
# retail_and_recreation_percent_change_from_baseline    float64
# grocery_and_pharmacy_percent_change_from_baseline     float64
# parks_percent_change_from_baseline                    float64
# transit_stations_percent_change_from_baseline         float64
# workplaces_percent_change_from_baseline               float64
# residential_percent_change_from_baseline              float64
# dtype: object

# %%
mobility_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 516697 entries, 0 to 516696
# Data columns (total 13 columns):
#  #   Column                                              Non-Null Count   Dtype
# ---  ------                                              --------------   -----
#  0   country_region_code                                 515810 non-null  object
#  1   country_region                                      516697 non-null  object
#  2   sub_region_1                                        501307 non-null  object
#  3   sub_region_2                                        298720 non-null  object
#  4   iso_3166_2_code                                     187299 non-null  object
#  5   census_fips_code                                    298834 non-null  float64
#  6   date                                                516697 non-null  object
#  7   retail_and_recreation_percent_change_from_baseline  400610 non-null  float64
#  8   grocery_and_pharmacy_percent_change_from_baseline   385086 non-null  float64
#  9   parks_percent_change_from_baseline                  238643 non-null  float64
#  10  transit_stations_percent_change_from_baseline       275427 non-null  float64
#  11  workplaces_percent_change_from_baseline             503228 non-null  float64
#  12  residential_percent_change_from_baseline            284348 non-null  float64
# dtypes: float64(7), object(6)
# memory usage: 51.2+ MB

# %%
mobility_df.describe()
# Out:
#        census_fips_code  retail_and_recreation_percent_change_from_baseline  \
# count     298834.000000                                      400610.000000
# mean       30341.084840                                         -23.909084
# std        15299.099769                                          29.054157
# min         1001.000000                                        -100.000000
# 25%        18111.000000                                         -44.000000
# 50%        29101.000000                                         -21.000000
# 75%        45059.000000                                           0.000000
# max        56045.000000                                         313.000000
#
#        grocery_and_pharmacy_percent_change_from_baseline  \
# count                                      385086.000000
# mean                                           -6.876116
# std                                            21.812352
# min                                          -100.000000
# 25%                                           -17.000000
# 50%                                            -3.000000
# 75%                                             6.000000
# max                                           337.000000
#
#        parks_percent_change_from_baseline  \
# count                       238643.000000
# mean                            -5.895145
# std                             47.914222
# min                           -100.000000
# 25%                            -38.000000
# 50%                             -9.000000
# 75%                             15.000000
# max                            616.000000
#
#        transit_stations_percent_change_from_baseline  \
# count                                  275427.000000
# mean                                      -28.052304
# std                                        30.077850
# min                                      -100.000000
# 25%                                       -52.000000
# 50%                                       -26.000000
# 75%                                        -3.000000
# max                                       497.000000
#
#        workplaces_percent_change_from_baseline  \
# count                            503228.000000
# mean                                -24.191545
# std                                  21.692744
# min                                 -94.000000
# 25%                                 -39.000000
# 50%                                 -26.000000
# 75%                                  -4.000000
# max                                 248.000000
#
#        residential_percent_change_from_baseline
# count                             284348.000000
# mean                                  10.976437
# std                                    9.470850
# min                                  -25.000000
# 25%                                    2.000000
# 50%                                   11.000000
# 75%                                   17.000000
# max                                   56.000000

# %%
# quite a lot of null values...
mobility_df.isnull().sum()
# Out:
# country_region_code                                      887
# country_region                                             0
# sub_region_1                                           15390
# sub_region_2                                          217977
# iso_3166_2_code                                       329398
# census_fips_code                                      217863
# date                                                       0
# retail_and_recreation_percent_change_from_baseline    116087
# grocery_and_pharmacy_percent_change_from_baseline     131611
# parks_percent_change_from_baseline                    278054
# transit_stations_percent_change_from_baseline         241270
# workplaces_percent_change_from_baseline                13469
# residential_percent_change_from_baseline              232349
# dtype: int64

# %%
# see top 10 countries with most data
mobility_df.groupby(["country_region"]).count().sort_values(by="country_region_code",ascending=False).head(10)
# Out:
#                 country_region_code  sub_region_1  sub_region_2  \
# country_region
# United States                304648        304534        298720
# United Kingdom                17260         17146             0
# Turkey                         9339          9225             0
# Puerto Rico                    7646          7532             0
# Vietnam                        7296          7182             0
# Slovenia                       5633          5519             0
# Japan                          5472          5358             0
# Romania                        4902          4788             0
# Nigeria                        4332          4218             0
# India                          4218          4104             0
#
#                 iso_3166_2_code  census_fips_code    date  \
# country_region
# United States              5814            298834  304648
# United Kingdom            16253                 0   17260
# Turkey                     9225                 0    9339
# Puerto Rico                   0                 0    7646
# Vietnam                    7182                 0    7296
# Slovenia                      0                 0    5633
# Japan                      5358                 0    5472
# Romania                    4788                 0    4902
# Nigeria                    4218                 0    4332
# India                      4104                 0    4218
#
#                 retail_and_recreation_percent_change_from_baseline  \
# country_region
# United States                                              219426
# United Kingdom                                              16844
# Turkey                                                       8701
# Puerto Rico                                                  5074
# Vietnam                                                      7295
# Slovenia                                                     3007
# Japan                                                        5472
# Romania                                                      4896
# Nigeria                                                      3300
# India                                                        4104
#
#                 grocery_and_pharmacy_percent_change_from_baseline  \
# country_region
# United States                                              207167
# United Kingdom                                              17031
# Turkey                                                       8561
# Puerto Rico                                                  5207
# Vietnam                                                      7060
# Slovenia                                                     2669
# Japan                                                        5472
# Romania                                                      4902
# Nigeria                                                      3268
# India                                                        4017
#
#                 parks_percent_change_from_baseline  \
# country_region
# United States                                77356
# United Kingdom                               13367
# Turkey                                        7918
# Puerto Rico                                   1776
# Vietnam                                       7254
# Slovenia                                       513
# Japan                                         5472
# Romania                                       4901
# Nigeria                                       2619
# India                                         4181
#
#                 transit_stations_percent_change_from_baseline  \
# country_region
# United States                                          119088
# United Kingdom                                          16769
# Turkey                                                   7226
# Puerto Rico                                               564
# Vietnam                                                  6768
# Slovenia                                                 1139
# Japan                                                    5472
# Romania                                                  4865
# Nigeria                                                  2428
# India                                                    4085
#
#                 workplaces_percent_change_from_baseline  \
# country_region
# United States                                    293793
# United Kingdom                                    17225
# Turkey                                             9339
# Puerto Rico                                        7296
# Vietnam                                            7296
# Slovenia                                           5244
# Japan                                              5472
# Romania                                            4902
# Nigeria                                            4332
# India                                              4218
#
#                 residential_percent_change_from_baseline
# country_region
# United States                                     138947
# United Kingdom                                     13323
# Turkey                                              7364
# Puerto Rico                                          854
# Vietnam                                             7112
# Slovenia                                             688
# Japan                                               5472
# Romania                                             4634
# Nigeria                                             2585
# India                                               4073

# %% [markdown]
# ### Deep dive into US mobility data

# %%
# filter mobility_df to united states
us = mobility_df["country_region"] == "United States"
us_df = mobility_df[us]

# %%
# rename columns


usCols = ['country_region_code', 'country_region', 'state', 'county', 'iso_3166_2_code', 'census_fips_code', 'date',
          'retail_and_recreation', 'grocery_and_pharmacy', 'parks', 'transit_stations', 'workplaces', 'residential']
us_df.columns = usCols

# %%
us_df.sample(10)
# Out:
#        country_region_code country_region       state               county  \
# 477816                  US  United States    Virginia    James City County
# 263981                  US  United States    Illinois          Kane County
# 313990                  US  United States   Louisiana         Union Parish
# 473815                  US  United States    Virginia  Chesterfield County
# 332697                  US  United States   Minnesota      Fillmore County
# 318376                  US  United States    Maryland       Harford County
# 268849                  US  United States    Illinois     Vermilion County
# 372924                  US  United States  New Mexico          Eddy County
# 373660                  US  United States  New Mexico    Los Alamos County
# 452637                  US  United States       Texas      Hardeman County
#
#        iso_3166_2_code  census_fips_code        date  retail_and_recreation  \
# 477816             NaN           51095.0  2020-04-29                  -42.0
# 263981             NaN           17089.0  2020-03-07                   18.0
# 313990             NaN           22111.0  2020-03-17                   10.0
# 473815             NaN           51041.0  2020-04-05                  -43.0
# 332697             NaN           27045.0  2020-02-23                   41.0
# 318376             NaN           24025.0  2020-03-23                  -37.0
# 268849             NaN           17183.0  2020-05-12                  -12.0
# 372924             NaN           35015.0  2020-03-27                  -36.0
# 373660             NaN           35028.0  2020-05-25                    NaN
# 452637             NaN           48197.0  2020-03-24                    NaN
#
#         grocery_and_pharmacy  parks  transit_stations  workplaces  residential
# 477816                 -11.0    NaN               NaN       -50.0         18.0
# 263981                  16.0  103.0              12.0         8.0         -3.0
# 313990                  29.0    NaN               NaN       -13.0          NaN
# 473815                 -24.0   19.0             -28.0       -41.0         12.0
# 332697                   7.0    NaN               NaN        -7.0          NaN
# 318376                 -19.0  -37.0             -45.0       -41.0         19.0
# 268849                   6.0    NaN              -3.0       -33.0         10.0
# 372924                 -10.0  -29.0             -18.0       -29.0         15.0
# 373660                   NaN    NaN               NaN       -81.0          NaN
# 452637                   6.0    NaN               0.0         NaN          NaN

# %% [markdown]
# Mobility data by States

# %%
# which states has most mobility data
state_df = us_df.groupby(["state"], as_index=False)["country_region_code"].count().sort_values(by="country_region_code",ascending=False)

#rename columns
state_df.columns = ["state", "mobility_counts"]
state_df.head()
# Out:
#              state  mobility_counts
# 43           Texas            22880
# 10         Georgia            16027
# 46        Virginia            14248
# 17        Kentucky            11259
# 33  North Carolina            11047

# %%
#us_df.groupby(["state"], as_index=False)
us_df.size
# Out:
# 3960424

# %%
us_df.isnull().sum()
# Out:
# country_region_code           0
# country_region                0
# state                       114
# county                     5928
# iso_3166_2_code          298834
# census_fips_code           5814
# date                          0
# retail_and_recreation     85222
# grocery_and_pharmacy      97481
# parks                    227292
# transit_stations         185560
# workplaces                10855
# residential              165701
# dtype: int64

# %% [markdown]
# ## Remove NaN from state and county: Not many nulls

# %%
us_df.dropna(subset=['state', 'county']).isnull().sum()
us_df_filtered = us_df.dropna(subset=['state', 'county'])
us_df_filtered.size
# Out:
# 3883360

# %%
state_list = us_df_filtered['state'].unique().tolist()

# %%
state_df = us_df_filtered[us_df_filtered['state']=='Texas']
state_df_sorted = state_df.sort_values(by=['date'], inplace=False)
state_df_sorted.plot(x='date', y='transit_stations')
state_df_sorted.head(10)
# Out:
#        country_region_code country_region  state            county  \
# 443937                  US  United States  Texas   Anderson County
# 456558                  US  United States  Texas       Leon County
# 456672                  US  United States  Texas    Liberty County
# 456786                  US  United States  Texas  Limestone County
# 456900                  US  United States  Texas   Live Oak County
# 457014                  US  United States  Texas      Llano County
# 457128                  US  United States  Texas     Loving County
# 457172                  US  United States  Texas    Lubbock County
# 457341                  US  United States  Texas    Madison County
# 457455                  US  United States  Texas     Marion County
#
#        iso_3166_2_code  census_fips_code        date  retail_and_recreation  \
# 443937             NaN           48001.0  2020-02-15                    3.0
# 456558             NaN           48289.0  2020-02-15                    7.0
# 456672             NaN           48291.0  2020-02-15                    3.0
# 456786             NaN           48293.0  2020-02-15                    0.0
# 456900             NaN           48297.0  2020-02-15                   16.0
# 457014             NaN           48299.0  2020-02-15                    0.0
# 457128             NaN           48301.0  2020-02-15                    NaN
# 457172             NaN           48303.0  2020-02-15                    4.0
# 457341             NaN           48313.0  2020-02-15                    1.0
# 457455             NaN           48315.0  2020-02-15                   -1.0
#
#         grocery_and_pharmacy  parks  transit_stations  workplaces  residential
# 443937                   1.0    NaN               NaN        -1.0          NaN
# 456558                   4.0    NaN               6.0         NaN          NaN
# 456672                  10.0    NaN              -7.0         6.0         -1.0
# 456786                   4.0    NaN               NaN        -5.0          NaN
# 456900                   6.0    NaN               9.0         6.0          NaN
# 457014                   6.0    6.0               NaN        -2.0          NaN
# 457128                 -24.0    NaN               NaN         NaN          NaN
# 457172                   3.0   26.0              -3.0         3.0         -1.0
# 457341                  13.0    NaN               NaN         NaN          NaN
# 457455                   5.0    NaN               NaN         NaN          NaN

# %%
us_df_filtered_texas['transit_stations'].interpolate(method='linear', inplace=True)
us_df_filtered_texas['grocery_and_pharmacy'].interpolate(method='linear', inplace=True)
us_df_filtered_texas['retail_and_recreation'].interpolate(method='linear', inplace=True)
us_df_filtered_texas['workplaces'].interpolate(method='linear', inplace=True)
us_df_filtered_texas['residential'].interpolate(method='linear', inplace=True)
us_df_filtered_texas['parks'].interpolate(method='linear', inplace=True)

print(us_df_filtered_texas.head(20))

us_df_filtered_texas = us_df_filtered_texas.fillna(value=None, method='backfill', axis=None, limit=None, downcast=None)

print(us_df_filtered_texas.isnull().sum())

print(us_df_filtered_texas.head(20))
# Out:
#        country_region_code country_region  state            county  \
# 443937                  US  United States  Texas   Anderson County
# 456558                  US  United States  Texas       Leon County
# 456672                  US  United States  Texas    Liberty County
# 456786                  US  United States  Texas  Limestone County
# 456900                  US  United States  Texas   Live Oak County
# 457014                  US  United States  Texas      Llano County
# 457128                  US  United States  Texas     Loving County
# 457172                  US  United States  Texas    Lubbock County
# 457341                  US  United States  Texas    Madison County
# 457455                  US  United States  Texas     Marion County
# 457551                  US  United States  Texas     Martin County
# 457647                  US  United States  Texas  Matagorda County
# 457761                  US  United States  Texas   Maverick County
# 457875                  US  United States  Texas  McCulloch County
# 457971                  US  United States  Texas   McLennan County
# 458163                  US  United States  Texas     Medina County
# 458277                  US  United States  Texas    Midland County
#
#         residential
# 443937    -1.000000
# 456558    -1.000000
# 456672    -1.000000
# 456786    -1.000000
# 456900    -1.000000
# 457014    -1.000000
# 457128    -1.000000
# 457172    -1.000000
# 457341    -1.200000
# 457455    -1.400000
# 457551    -1.600000
# 457647    -1.800000
# 457761    -2.000000
# 457875    -1.500000
# 457971    -1.000000
# 458163    -1.500000
# 458277    -2.000000
# 458391    -1.777778
# 456447    -1.555556
# 458505    -1.333333

# %%
us_df_texas = us_df_filtered[us_df_filtered['state']=='California']
us_df_filtered_texas = us_df_texas.sort_values(by=['date'], inplace=False)
us_df_filtered_texas.plot(x='date', y='grocery_and_pharmacy')

# %% [markdown]
# ## Sort data by date

# %%
for i,j in enumerate(state_list):

    state_df = us_df_filtered[us_df_filtered['state']==state_list[i]]
    state_df_sorted = state_df.sort_values(by=['date'], inplace=False)
   
    
    state_df_sorted['transit_stations'].interpolate(method='linear', inplace=True)
    state_df_sorted['grocery_and_pharmacy'].interpolate(method='linear', inplace=True)
    state_df_sorted['retail_and_recreation'].interpolate(method='linear', inplace=True)
    state_df_sorted['workplaces'].interpolate(method='linear', inplace=True)
    state_df_sorted['residential'].interpolate(method='linear', inplace=True)
    state_df_sorted['parks'].interpolate(method='linear', inplace=True)

state_df_sorted = state_df_sorted.fillna(value=None, method='backfill', axis=None, limit=None, downcast=None)

# %%
state_df_sorted.plot(x='date', y='transit_stations')

# %%
state_df_sorted.isnull().sum()
# Out:
# country_region_code         0
# country_region              0
# state                       0
# county                      0
# iso_3166_2_code          2160
# census_fips_code            0
# date                        0
# retail_and_recreation       0
# grocery_and_pharmacy        0
# parks                       0
# transit_stations            0
# workplaces                  0
# residential                 0
# dtype: int64

# %%
state_df_sorted.head(20)
# Out:
#        country_region_code country_region    state             county  \
# 502378                  US  United States  Wyoming      Albany County
# 504368                  US  United States  Wyoming    Washakie County
# 502695                  US  United States  Wyoming      Carbon County
# 504254                  US  United States  Wyoming       Uinta County
# 502809                  US  United States  Wyoming    Converse County
# 504140                  US  United States  Wyoming       Teton County
# 502968                  US  United States  Wyoming     Fremont County
# 503082                  US  United States  Wyoming      Goshen County
# 504026                  US  United States  Wyoming  Sweetwater County
# 503188                  US  United States  Wyoming     Johnson County
# 503276                  US  United States  Wyoming     Laramie County
# 503937                  US  United States  Wyoming    Sublette County
# 503390                  US  United States  Wyoming     Lincoln County
# 503823                  US  United States  Wyoming    Sheridan County
# 503499                  US  United States  Wyoming     Natrona County
# 503613                  US  United States  Wyoming        Park County
# 502581                  US  United States  Wyoming    Campbell County
# 502492                  US  United States  Wyoming    Big Horn County
# 503727                  US  United States  Wyoming      Platte County
# 503083                  US  United States  Wyoming      Goshen County
#
#         iso_3166_2_code  census_fips_code        date  retail_and_recreation  \
# 502378              NaN           56001.0  2020-02-15                    6.0
# 504368              NaN           56043.0  2020-02-15                    6.0
# 502695              NaN           56007.0  2020-02-15                  -12.0
# 504254              NaN           56041.0  2020-02-15                    9.0
# 502809              NaN           56009.0  2020-02-15                   -7.0
# 504140              NaN           56039.0  2020-02-15                   -1.0
# 502968              NaN           56013.0  2020-02-15                    7.0
# 503082              NaN           56015.0  2020-02-15                  -14.0
# 504026              NaN           56037.0  2020-02-15                    2.0
# 503188              NaN           56019.0  2020-02-15                   -1.0
# 503276              NaN           56021.0  2020-02-15                    2.0
# 503937              NaN           56035.0  2020-02-15                    0.0
# 503390              NaN           56023.0  2020-02-15                   18.0
# 503823              NaN           56033.0  2020-02-15                   -4.0
# 503499              NaN           56025.0  2020-02-15                    3.0
# 503613              NaN           56029.0  2020-02-15                    9.0
# 502581              NaN           56005.0  2020-02-15                    4.0
# 502492              NaN           56003.0  2020-02-15                    5.0
# 503727              NaN           56031.0  2020-02-15                   11.0
# 503083              NaN           56015.0  2020-02-16                    4.0
#
#         grocery_and_pharmacy  parks  transit_stations  workplaces  residential
# 502378                  -5.0  6.000        -29.000000        -4.0       -1.000
# 504368                  -9.0  6.000        -37.000000        -3.0       -1.000
# 502695                 -13.0  6.000        -45.000000        -2.0       -1.000
# 504254                  15.0  6.000        -27.000000         5.0       -1.000
# 502809                 -13.0  6.000         -8.000000        -9.0       -1.000
# 504140                  -3.0  6.000         11.000000         7.0       -1.000
# 502968                   4.0  5.000         -3.666667         1.0       -1.000
# 503082                  -1.0  4.000        -18.333333         1.0       -1.000
# 504026                   9.0  3.000        -33.000000         1.0       -1.000
# 503188                   6.0  2.000        -15.000000         0.5       -1.000
# 503276                   3.0  1.000          3.000000         0.0       -1.000
# 503937                 -21.0  0.250          4.500000         3.0       -0.750
# 503390                  12.0 -0.500          6.000000         6.0       -0.500
# 503823                   5.0 -1.250          7.500000         3.0       -0.250
# 503499                  -1.0 -2.000          9.000000        -1.0        0.000
# 503613                  25.0 -2.375         11.500000         1.0       -0.125
# 502581                   8.0 -2.750         14.000000         2.0       -0.250
# 502492                  14.0 -3.125          1.600000         1.2       -0.375
# 503727                   3.0 -3.500        -10.800000         0.4       -0.500
# 503083                   3.0 -3.875        -23.200000        -0.4       -0.625

# %%
data_preprocess = "./US_Mobility_Report_preprocess.csv"
state_df_sorted.to_csv (data_preprocess, index = False, header=True)

# %% [markdown]
# ## Plot EDA result

# %%
g = sns.FacetGrid(state_df, col="state", col_wrap=5, height=2)
g = g.map(plt.bar, "state", "mobility_counts", color="r")

# %% [markdown]
# Mobility data by locations

# %%
# group by locations to see which locations have the most mobility data
location_df = us_df.groupby(["country_region"]).count()
# location_df = us_df.groupby(['retail_and_recreation',
#        'grocery_and_pharmacy', 'parks', 'transit_stations', 'workplaces',
#        'residential'], as_index=False)["country_region_code"].count().sort_values(by="country_region_code",ascending=False)

# transpose dataframe 
location_df = location_df.transpose()

# selection locations by count of data
location_df = location_df.loc[["retail_and_recreation", "grocery_and_pharmacy", "parks", "transit_stations", "workplaces", "residential"]].reset_index()

# rename columns
location_df.columns = ["location", "mobility_count"]

# %%
# plot location_df to see mobility data by location
plt.figure(figsize=(15,5))
ax = sns.barplot(x="location", y="mobility_count", 
                 data=location_df)

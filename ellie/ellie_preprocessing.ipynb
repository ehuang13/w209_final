# %%
# imports
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# read in peter's preprocessed US Mobility datset
data = "https://raw.githubusercontent.com/ehuang13/w209_final/master/data/US_Mobility_Report_preprocess.csv"
us_df = pd.read_csv(data, low_memory = False)

# %%
# checkout the data
us_df.sample(10)
# Out:
#        country_region_code country_region           state  \
# 231414                  US  United States       Tennessee
# 273355                  US  United States        Virginia
# 204223                  US  United States        Oklahoma
# 127619                  US  United States        Michigan
# 270706                  US  United States        Virginia
# 208055                  US  United States        Oklahoma
# 277113                  US  United States        Virginia
# 178834                  US  United States  North Carolina
# 74070                   US  United States         Indiana
# 179857                  US  United States  North Carolina
#
#                       county  iso_3166_2_code  census_fips_code       date  \
# 231414         Wilson County              NaN             47189  3/15/2020
# 273355  Isle of Wight County              NaN             51093  4/14/2020
# 204223          Creek County              NaN             40037  3/23/2020
# 127619         Benzie County              NaN             26019   6/6/2020
# 270706           Buena Vista              NaN             51530  3/24/2020
# 208055          Mayes County              NaN             40097  5/23/2020
# 277113    Northampton County              NaN             51131  5/15/2020
# 178834         Yancey County              NaN             37199  2/15/2020
# 74070         Steuben County              NaN             18151  4/17/2020
# 179857            Lee County              NaN             37105  2/26/2020
#
#         retail_and_recreation  grocery_and_pharmacy       parks  \
# 231414              -4.000000             13.000000   23.000000
# 273355             -41.000000             -5.000000  -13.500000
# 204223             -20.000000              1.000000   31.952381
# 127619              -7.500000             12.000000  152.642857
# 270706             -43.000000              1.000000   73.000000
# 208055               8.000000             44.000000   13.357143
# 277113             -25.142857              2.666667    7.200000
# 178834              11.000000              8.000000    3.000000
# 74070              -46.000000            -24.000000  -12.750000
# 179857              15.000000              4.000000   -0.888889
#
#         transit_stations  workplaces  residential
# 231414          9.000000        -9.0     3.000000
# 273355        -58.714286       -40.0    17.000000
# 204223        -10.400000       -29.0    13.000000
# 127619          8.222222         1.0     1.333333
# 270706        -11.200000       -25.0    11.500000
# 208055         14.200000       -11.0     2.500000
# 277113         -6.000000       -34.0    12.307692
# 178834          5.000000         6.0    -0.764706
# 74070         -34.000000       -43.0    20.428571
# 179857          0.000000         1.0     0.000000

# %% [markdown]
# ### Calculate Average change Across Different Locations

# %%
average_cols = list(us_df[['retail_and_recreation',
       'grocery_and_pharmacy', 'parks', 'transit_stations', 'workplaces',
       'residential']].mean(axis=1))

# %%
us_df["avg_change"] = average_cols

# %%
us_df.sample(5)
# Out:
#        country_region_code country_region         state              county  \
# 251973                  US  United States         Texas       Potter County
# 89811                   US  United States        Kansas        Cloud County
# 189733                  US  United States  North Dakota  Grand Forks County
# 28754                   US  United States      Colorado     Gunnison County
# 102671                  US  United States      Kentucky   Rockcastle County
#
#         iso_3166_2_code  census_fips_code       date  retail_and_recreation  \
# 251973              NaN             48375  4/18/2020                  -34.0
# 89811               NaN             20029   3/9/2020                   -3.0
# 189733              NaN             38035  2/18/2020                    3.0
# 28754               NaN              8051  5/31/2020                  -28.0
# 102671              NaN             21203   5/3/2020                  -13.8
#
#         grocery_and_pharmacy      parks  transit_stations  workplaces  \
# 251973                  -8.0  -8.000000        -22.000000       -21.0
# 89811                    7.0  -2.800000         10.000000       -11.0
# 189733                  -6.0   1.200000          1.000000         3.0
# 28754                   -6.0  73.000000        -14.500000       -35.0
# 102671                   0.4  62.333333        -10.444444       -21.0
#
#         residential  avg_change
# 251973     9.000000  -14.000000
# 89811      0.857143    0.176190
# 189733     0.000000    0.366667
# 28754      4.666667   -0.972222
# 102671     8.142857    4.271958

# %%
# confirm type for location columns
us_df[['retail_and_recreation',
       'grocery_and_pharmacy', 'parks', 'transit_stations', 'workplaces',
       'residential',"avg_change"]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 298720 entries, 0 to 298719
# Data columns (total 7 columns):
# retail_and_recreation    298720 non-null float64
# grocery_and_pharmacy     298720 non-null float64
# parks                    298720 non-null float64
# transit_stations         298720 non-null float64
# workplaces               298720 non-null float64
# residential              298720 non-null float64
# avg_change               298720 non-null float64
# dtypes: float64(7)
# memory usage: 16.0 MB

# %% [markdown]
# ### Export US Mobility Data to CSV File For Tableau Work

# %%
us_df.to_csv("US_Mobility_Report_preprocess.csv")

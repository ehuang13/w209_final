# %%
# imports
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
# read in peter's preprocessed US Mobility datset
data = "https://raw.githubusercontent.com/ehuang13/w209_final/master/data/US_Mobility_Report_preprocess.csv"
us_df = pd.read_csv(data, low_memory = False)

# %%
# checkout the data
us_df.sample(10)
# Out:
#         Unnamed: 0 country_region_code country_region          state  \
# 101948      101948                  US  United States       Kentucky
# 281612      281612                  US  United States     Washington
# 121135      121135                  US  United States       Michigan
# 164940      164940                  US  United States         Nevada
# 284345      284345                  US  United States  West Virginia
# 278006      278006                  US  United States       Virginia
# 126824      126824                  US  United States       Michigan
# 289068      289068                  US  United States      Wisconsin
# 90217        90217                  US  United States         Kansas
# 18              18                  US  United States        Alabama
#
#                        county  iso_3166_2_code  census_fips_code       date  \
# 101948          Harlan County              NaN             21095  4/25/2020
# 281612            King County              NaN             53033   4/3/2020
# 121135       Kalamazoo County              NaN             26077  3/15/2020
# 164940          Storey County              NaN             32029   6/1/2020
# 284345           Boone County              NaN             54005  2/25/2020
# 278006       Dickenson County              NaN             51051  5/22/2020
# 126824  Grand Traverse County              NaN             26055  5/27/2020
# 289068       La Crosse County              NaN             55063  2/19/2020
# 90217        McPherson County              NaN             20113  3/16/2020
# 18              Sumter County              NaN              1119  2/15/2020
#
#         retail_and_recreation  grocery_and_pharmacy       parks  \
# 101948                  -30.0            -18.428571  -45.130435
# 281612                  -56.0            -21.000000  -18.000000
# 121135                  -13.0              2.000000  160.000000
# 164940                   -8.0              1.500000  -23.000000
# 284345                   16.0             -3.000000  -10.454545
# 278006                  -12.5              9.666667   25.400000
# 126824                  -10.0              1.000000  103.000000
# 289068                   -1.0             -1.000000   -5.000000
# 90217                     0.0             19.000000    0.200000
# 18                       -6.0            -11.000000   18.600000
#
#         transit_stations  workplaces  residential  avg_change
# 101948        -27.428571        -4.0    11.571429  -18.902692
# 281612        -72.000000       -69.0    31.000000  -34.166667
# 121135        -12.000000        -5.0     2.000000   22.333333
# 164940        -21.333333       -40.0    12.500000  -13.055556
# 284345          7.833333         2.0     0.000000    2.063131
# 278006        -18.000000       -30.0    18.800000   -1.105556
# 126824        -47.000000       -34.0    11.000000    4.000000
# 289068         -2.000000         2.0     0.000000   -1.166667
# 90217          -3.000000       -16.0     6.000000    1.033333
# 18              6.333333         3.5    -0.500000    1.822222

# %% [markdown]
# ### Calculate `Average Change` Across Different Locations

# %%
average_cols = list(us_df[['retail_and_recreation',
       'grocery_and_pharmacy', 'parks', 'transit_stations', 'workplaces',
       'residential']].mean(axis=1))

# %%
us_df["avg_change"] = average_cols

# %%
us_df.sample(5)
# Out:
#         Unnamed: 0 country_region_code country_region           state  \
# 158597      158597                  US  United States        Nebraska
# 213123      213123                  US  United States    Pennsylvania
# 108916      108916                  US  United States       Louisiana
# 182897      182897                  US  United States  North Carolina
# 29148        29148                  US  United States     Connecticut
#
#                   county  iso_3166_2_code  census_fips_code       date  \
# 158597    Stanton County              NaN             31167  2/19/2020
# 213123      Tioga County              NaN             42117  2/20/2020
# 108916  Lafourche Parish              NaN             22057   4/2/2020
# 182897       Ashe County              NaN             37009  3/28/2020
# 29148    Hartford County              NaN              9003  2/23/2020
#
#         retail_and_recreation  grocery_and_pharmacy      parks  \
# 158597                  -12.5                  -4.5   3.346154
# 213123                    7.0                  -1.0   1.333333
# 108916                  -26.0                  -6.0 -13.200000
# 182897                  -18.0                  16.0  44.000000
# 29148                     8.0                  -1.0  81.000000
#
#         transit_stations  workplaces  residential  avg_change
# 158597         -4.333333         8.0     0.800000   -1.531197
# 213123          4.000000        -1.0     1.000000    1.888889
# 108916        -40.000000       -37.0    16.000000  -17.700000
# 182897        -44.000000       -27.0     7.333333   -3.611111
# 29148          11.000000         3.0    -1.000000   16.833333

# %%
# confirm type for location columns
us_df[['retail_and_recreation',
       'grocery_and_pharmacy', 'parks', 'transit_stations', 'workplaces',
       'residential',"avg_change"]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 298720 entries, 0 to 298719
# Data columns (total 7 columns):
# retail_and_recreation    298720 non-null float64
# grocery_and_pharmacy     298720 non-null float64
# parks                    298720 non-null float64
# transit_stations         298720 non-null float64
# workplaces               298720 non-null float64
# residential              298720 non-null float64
# avg_change               298720 non-null float64
# dtypes: float64(7)
# memory usage: 16.0 MB

# %%
# drop extra ID column
us_df = us_df.drop(columns = ['Unnamed: 0'])

# %%
us_df.sample(5)
# Out:
#        country_region_code country_region           state             county  \
# 55696                   US  United States           Idaho    Kootenai County
# 186907                  US  United States  North Carolina     Chatham County
# 213998                  US  United States    Pennsylvania  Huntingdon County
# 117588                  US  United States   Massachusetts    Plymouth County
# 225820                  US  United States  South Carolina    Florence County
#
#         iso_3166_2_code  census_fips_code       date  retail_and_recreation  \
# 55696               NaN             16055  3/28/2020                  -47.0
# 186907              NaN             37037   5/9/2020                  -12.0
# 213998              NaN             42061   3/5/2020                   14.0
# 117588              NaN             25023   3/6/2020                    2.0
# 225820              NaN             45041   6/7/2020                   -4.0
#
#         grocery_and_pharmacy      parks  transit_stations  workplaces  \
# 55696                  -20.0  32.000000             -19.0       -34.0
# 186907                  13.0  61.200000              -0.8       -23.0
# 213998                   5.0  71.333333               9.0         4.0
# 117588                   4.0   6.000000              -4.0         1.0
# 225820                  11.0   3.000000              32.0       -17.0
#
#         residential  avg_change
# 55696          12.0  -12.666667
# 186907          6.5    7.483333
# 213998         -1.0   17.055556
# 117588          1.0    1.666667
# 225820          4.0    4.833333

# %% [markdown]
# ### Export US Mobility Data to CSV File For Tableau Work

# %%
us_df.to_csv("US_Mobility_Report_preprocess.csv")

# %% [markdown]
# ### Calculate `Abs(Avg Change)` to Understand Magnitude of Movement

# %%
abs_avg_change = []
for i in us_df["avg_change"]:
    i = abs(i)
    abs_avg_change.append(i)

# %%
us_df["abs_avg_change"] = abs_avg_change

# %%
us_df.sample(5)
# Out:
#        country_region_code country_region           state           county  \
# 216707                  US  United States    Pennsylvania  Bradford County
# 26852                   US  United States        Colorado    Teller County
# 180604                  US  United States  North Carolina   Halifax County
# 190174                  US  United States    North Dakota    McLean County
# 296718                  US  United States         Wyoming    Carbon County
#
#         iso_3166_2_code  census_fips_code       date  retail_and_recreation  \
# 216707              NaN             42015  4/16/2020                  -27.0
# 26852               NaN              8119  4/19/2020                  -34.5
# 180604              NaN             37083   3/5/2020                   16.0
# 190174              NaN             38055  3/12/2020                   20.0
# 296718              NaN             56007  2/23/2020                    8.0
#
#         grocery_and_pharmacy      parks  transit_stations  workplaces  \
# 216707                  -2.0  -5.285714        -39.666667       -36.0
# 26852                  -13.5  -0.500000        -35.000000       -42.0
# 180604                   3.0   8.000000         11.250000         1.0
# 190174                  26.5   0.125000         10.250000         8.0
# 296718                   5.0  21.125000          1.000000        -2.0
#
#         residential  avg_change  abs_avg_change
# 216707    16.000000  -15.658730       15.658730
# 26852     14.666667  -18.472222       18.472222
# 180604    -2.000000    6.208333        6.208333
# 190174    -1.000000   10.645833       10.645833
# 296718    -1.000000    5.354167        5.354167
